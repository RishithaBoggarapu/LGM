# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image=cv2.imread("/content/img.jpg")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=249x202 at 0x7F9CE8026950>

# %%
#grayscale image
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=249x202 at 0x7F9CD4F5CE90>

# %%
#negative image
inverted_image=255-gray_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=249x202 at 0x7F9CD4F6A490>

# %%
#blur image
blurred=cv2.GaussianBlur(inverted_image,(21,21),0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=249x202 at 0x7F9CD4F5CE50>

# %%
inverted_blurred=255-blurred
pencil_sketch=cv2.divide(gray_image,inverted_blurred,scale=256.0)
#Original image
cv2_imshow(image)
#pencil sketch
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=249x202 at 0x7F9CD4F6E450>
# <PIL.Image.Image image mode=L size=249x202 at 0x7F9CD4F6AC90>
